# %% [markdown]
# <a href="https://colab.research.google.com/github/chenyilow/cyl68_ads_2024/blob/main/_notebooks/ads_course_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assessment for Advanced Data Science
# # *Data Pipelines*

# %% [markdown]
# ## Radzim Sendyka, Christian Cabrera, Carl Henrik Ek and Neil D. Lawrence
#
# ### 19 November 2024

# %% [markdown]
# Welcome to the course assessment for the Advanced Data Science unit. In this assessment, you will build two data pipelines and prediction systems.
#
# The maximum total mark for this assessment is 20. That mark is split into two miniprojects below.
# - The first miniproject is worth 7 marks.
# - The second miniproject is worth 13 marks.
#
# *The check Session for this Assessment is 03 December 2024.*

# %% [markdown]
# # Task 1 (7 marks)

# %% [markdown]
# This example project builds on your experience from the practicals, using Open Street Maps, and connecting them to real-world datasets.
#
# Your prediction system will be based on data from the 2021 UK Census, and Open Street Maps.

# %% [markdown]
# ### Build a data pipeline and prediction system.
#
# Structure your system around the [Access-Assess-Address](https://inverseprobability.com/talks/notes/access-assess-address-a-pipeline-for-automated-data-science.html) framework for automated data science.
# Use the framework of [Data Readiness Levels](https://inverseprobability.com/publications/data-readiness-levels.html) to track the state of your datasets throughout the process.
# Visualise your data and predictions using appropriate charts and graphics.
# Remember, your notebook should tell a story.
#
# 1.1. Download the data from online sources. In this task you will need:
#   - UK Census Data
#     - The UK Census data file for and Socio-economic Classification (NS SEC) [here](https://www.ons.gov.uk/datasets/TS062/editions/2021/versions/5) or [here](https://www.nomisweb.co.uk/sources/census_2021_bulk). Use the most detailed area type (Output Areas).
#     - One other UK Census data file of your choosing [here](https://www.ons.gov.uk/search?topics=9731,6646,3845,9497,4262,4128,7755,4994,6885,9724,7367&filter=datasets) or [here](https://www.nomisweb.co.uk/sources/census_2021_bulk). Use the most detailed area type available.
#     - Geographic coordinates of Census Output Areas [here](https://www.data.gov.uk/dataset/4d4e021d-fe98-4a0e-88e2-3ead84538537/output-areas-december-2021-boundaries-ew-bgc-v2).
#   - Spatial data
#     - Set up an API connection to Open Street Maps [here](https://osmnx.readthedocs.io/en/stable/). Optionally, to be able to use more data in training, you might want to also download the entire map for England (or more) [here](https://download.openstreetmap.fr/extracts/) or [here](https://wiki.openstreetmap.org/wiki/Planet.osm).
#
# 1.2. Structure the data, and upload it to your AWS database.
#
# - Census datasets can be huge and unwieldy to manipulate directly in python frameworks such as pandas. As a result we will host the data in a relational database.
#
# - Using a cloud hosted database (such as MariaDB hosted on the AWS RDS service),  you will construct a database containing tables that contain per-output-area data, latitudes and longitudes of the output areas, and potentially, extracted selected open street maps features from the country-wide data file.
#
# - Make sure you set the correct indices on your data, which will allow your code to run much faster. Hint: create an index on any columns you will be looking up, and joint indices if your lookup involves multiple columns (like coordinates).
#
# You will likely find the following resources helpful.
#
# - Lecture 1, 2 and 3.
# - Lab class 1 and 2.
#
#
# - *Note, this particular dataset could probably be handled directly in pandas, but you are explicitly tasked with using a database. This is a compromise from previous iterations of this course, where students spent quite a lot of time struggling from the size of the data. This is an opportunity for you to demonstrate your skills, as well as prepare for the second part of the assessment where databases might be necessary. Approach that do not use databases where needed will be penalised during marking.*
#
#
# 2.0. Explore the data.
#
#   - To make predictions you will augment your data with information obtained from Open Street Map: an open license source of mapping information. You will need to use the techniques you have learnt in the course to indentify and incorporate useful features for your prediction tasks.
#   - Look at the percentage of students (NS SEC code L15) in the individual output areas, and explore how it's related to various types of open street map features in those locations. Use the relationships you found to suggest the features to be used in a system that predicts percentage of students in a given area.
#   - Do the same for an additional census variable (e.g., the average age in a given area).
#
# 3.0. Make a prediction system.
# - Use Open Street Maps to predict Socio-Economic Status - in particular, the percent of full time students, from OSM features. Your function should take as input a coordinate pair (you can assume it will be in England), and return an estimate for the share of students in that area.
#
# - Do the same for the additional census variable you selected in the previous step.
#
# Hints:
#
#   - *Some of the census data sheets are very detailed. You might want to try "boiling them down" to some aggregate value or selecting just the most important columns.*
#
#   - *This assignment is focused on data pipelines, rather than machine learning, so we do not expect any advanced architectures here - a linear model or similar is perfectly fine.*
#
#   - *For data exploration, or picking your second dataset, you may find useful the [interactive map](https://www.ons.gov.uk/census/maps/) of the census data.*

# %% [markdown]
# ### Story.
#
# - Remember the notebook you create should tell a story, any code that is not critical to that story can safely be placed into the associated analysis library and imported for use (structured as given in the Fynesse template). Make sure your decisions are well substanciated and flow nicely throughout the notebook, with clear explanations.
#
# - Explain everything you do. Why is your question important, why you selected the datasets you did, why did you join them how you did, why did you look at the things you looked at.
#
# Make sure in your notebook you discuss the design decisions you made in your pipeline and prediction system. How did you structure your notebook? How did you track data readiness? Which aspects of your system could be improved further?
#
# Make sure you compare how you predict student population and your second chosen property. What differences are there, in the underlying data, process, and results?
#
# Make sure you discuss the reusability of your data pipeline and prediction system. What changes to the underlying data/system is it resilient to, and what isn't it? What work would need to be done to adjust it to answer questions about other statistics, or a different country, instead?

# %% [markdown]
# ### Fynesse library.
#
# - Alongside your implementation you will provide a short repository overview describing how you have implemented the different parts of the project and where you have placed those parts in your code repository. You will submit your code alongside a version of this notebook that will allow your examiner to understand and reconstruct the thinking behind your analysis. This notebook is structured to help you in creating that description and allow you to understand how we will allocate the marks. You should make use of the Fynesse framework (https://github.com/lawrennd/fynesse_template) for structuring your code.
#
# - One artefact to be included in your submission is a python library structured according to the "Access, Assess, Address" standard for data science solutions. You will submit this library alongside your code. Use the cell below to perform the necessary installation instructions for your library.
# You should base your module on the template repository given by the Fynesse template repository. That should make it pip-installable as below.
# `%pip install git+https://github.com/lawrennd/fynesse_template.git`. You can either replace fynesse with the name you've given your analysis module or you can leave the name as fynesse if you prefer.
#
# - Remember the notebook you create should tell a story, any code that is not critical to that story can safely be placed into the associated analysis library and imported for use (structured as given in the Fynesse template). Remember to include you fynesse library in your submission.

# %% [markdown]
# ## Access

# %% [markdown]
# ###1.1

# %% [markdown]
# We will first download UK Census Data for
# 1. TS062: National Statistics Socio-economic Classification,
# 2. TS037: General Health,
# 3. Geographic Coordinates of Census Output Areas,
#
# and OSM data for
# 4. Open Street Maps API Connection,
# 5. Map of England.

# %% [markdown]
# First, let us install and import the required libraries.

# %%
# install your library here
# %pip install git+https://github.com/lawrennd/fynesse_template.git # TODO: change to your library
# %pip install osmnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 6.5 MB/s eta 0:00:00
# ...

# %%
# %pip install pymysql
# %pip uninstall --yes fynesse
# %pip install git+https://github.com/chenyilow/cyl68_ads_2024.git
# Out:
# ...
# WARNING: Skipping fynesse as it is not installed.
# ...
#   Cloning https://github.com/chenyilow/cyl68_ads_2024.git to /tmp/pip-req-build-jvdlzu0i
#   Running command git clone --filter=blob:none --quiet https://github.com/chenyilow/cyl68_ads_2024.git /tmp/pip-req-build-jvdlzu0i
#   Resolved https://github.com/chenyilow/cyl68_ads_2024.git to commit 4d2c5aee73943762ed200c38d64881b35c3a1d68
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 35.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import osmnx as ox
# TODO: more imports here
import fynesse
import os
import requests

# %% [markdown]
# ### 1.1.1 TS062: National Statistics Socio-economic Classification

# %% [markdown]
# The following datasets are all retrieved using the Fynesse library, from the Access component. This is because all the downloads here have been done in previous practicals, and it is meaningless to repeat the code. Moreover, the functions in the Fynesse library allow us to specify which datasets we want (e.g. TS062 or TS037).

# %%
# Your code here

fileName = "TS062"
fynesse.access.download_census_data(fileName) # Age by single year of age
age_df = fynesse.access.load_census_data(fileName, level='oa')
age_df
# Out:
# Files extracted to: census2021-ts062
#         date  geography geography code  \
# 0       2021  E00000001      E00000001
# 1       2021  E00000003      E00000003
# 2       2021  E00000005      E00000005
# 3       2021  E00000007      E00000007
# 4       2021  E00000010      E00000010
# ...      ...        ...            ...
# 188875  2021  W00010693      W00010693
# 188876  2021  W00010694      W00010694
# 188877  2021  W00010695      W00010695
# 188878  2021  W00010696      W00010696
# 188879  2021  W00010697      W00010697
#
#         National Statistics Socio-economic Classification (NS-SEC): Total: All usual residents aged 16 years and over  \
# 0                                                     159
# 1                                                     222
# 2                                                     103
# 3                                                     140
# 4                                                     170
# ...

# %% [markdown]
# This DataFrame raised my suspicion -- `geography` and `geography code` appears to be the same data. We can do a simple test to find rows that have different `geography` and `geography code`s:

# %%
age_df[age_df["geography"] != age_df["geography code"]]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# This confirmed they are basically the same value for every single row, so we will exclude that in our uploading to the AWS database later on. Note that we still include every other column because we do not want to waste our Access efforts -- we might require the data later on in the project. For now, we will save the table in a .csv file so we can store it in the AWS database.

# %%
age_df = age_df.drop(columns=['geography'])
age_df.to_csv("age.csv", header=None, index=False)

# %% [markdown]
# ### 1.1.2 TS037: General Health

# %% [markdown]
# We repeat the process for another Census Data:
# 1. check that the `geography` and `geography code` columns are exactly the same, and remove if they are,
# 2. convert them to a .csv file.

# %%
# Your code here

fileName = "TS037"
fynesse.access.download_census_data(fileName) # Age by single year of age
health_df = fynesse.access.load_census_data(fileName, level='oa')
health_df.to_csv("health.csv", header=None, index=False)
health_df
# Out:
# Files extracted to: census2021-ts037
#         date  geography geography code  \
# 0       2021  E00000001      E00000001
# 1       2021  E00000003      E00000003
# 2       2021  E00000005      E00000005
# 3       2021  E00000007      E00000007
# 4       2021  E00000010      E00000010
# ...      ...        ...            ...
# 188875  2021  W00010693      W00010693
# 188876  2021  W00010694      W00010694
# 188877  2021  W00010695      W00010695
# 188878  2021  W00010696      W00010696
# 188879  2021  W00010697      W00010697
#
#         General health: Total: All usual residents  \
# 0                                              175
# 1                                              256
# 2                                              112
# 3                                              144
# 4                                              174
# ...                                            ...
# 188875                                         740
# ...

# %%
health_df[health_df["geography"] != health_df["geography code"]]
# Out:
# Empty DataFrame
# Columns: [date, geography, geography code, General health: Total: All usual residents, General health: Very good health, General health: Good health, General health: Fair health, General health: Bad health, General health: Very bad health]
# Index: []

# %%
health_df = health_df.drop(columns=['geography'])
health_df.to_csv("health.csv", header=None, index=False)

# %% [markdown]
# ###1.1.3 Geographic Coordinates of Census Output Areas

# %% [markdown]
# Note that below, since `OA21CD` represents the unique code for each Output Area, it is likely we will be joining this with the Census data above later.

# %%
fynesse.access.download_census_coord_data()
census_coord = gpd.GeoDataFrame(fynesse.access.load_census_coord_data())
census_coord.to_csv("census_coord.csv", header=None, index=False)
census_coord
# Out:
# File already exists at: shapefile.
#            OA21CD   LSOA21CD              LSOA21NM             LSOA21NMW  \
# 0       E00000001  E01000001   City of London 001A                  None
# 1       E00000003  E01000001   City of London 001A                  None
# 2       E00000005  E01000001   City of London 001A                  None
# 3       E00000007  E01000001   City of London 001A                  None
# 4       E00000010  E01000003   City of London 001C                  None
# ...           ...        ...                   ...                   ...
# 188875  W00010693  W01000062          Gwynedd 001A          Gwynedd 001A
# 188876  W00010694  W01000645  Carmarthenshire 006C  Sir Gaerfyrddin 006C
# 188877  W00010695  W01000664  Carmarthenshire 016C  Sir Gaerfyrddin 016C
# 188878  W00010696  W01001923  Carmarthenshire 026G  Sir Gaerfyrddin 026G
# 188879  W00010697  W01000667  Carmarthenshire 023C  Sir Gaerfyrddin 023C
#
#          BNG_E   BNG_N      LAT     LONG  \
# ...

# %% [markdown]
# ### 1.1.4 Open Street Maps API Connection

# %% [markdown]
# This is a similar exercise to Practical 2, so we just import the function we have already saved to our Fynesse library.

# %%
tags = {
    "amenity": True,
    "buildings": True,
    "historic": True,
    "leisure": True,
    "shop": True,
    "tourism": True,
    "religion": True,
    "memorial": True
}

osmnx_df = fynesse.access.download_osmnx_data(52.1951, 0.1313, tags) #Cambridge coordinates
osmnx_df.to_csv("osmnx.csv", header=None, index=False)
osmnx_df
# Out:
#                                                              geometry  \
# element id
# node    20823646                             POINT (0.12613 52.20262)
#         20823709                             POINT (0.13055 52.20086)
#         20823843                             POINT (0.13038 52.20478)
#         20826694                             POINT (0.13919 52.20238)
#         20826702                             POINT (0.13885 52.19961)
# ...                                                               ...
# way     1337666662  POLYGON ((0.13464 52.1874, 0.13528 52.18621, 0...
#         1337672054  POLYGON ((0.13089 52.18904, 0.1313 52.18913, 0...
#         1337674625  POLYGON ((0.12259 52.19495, 0.12261 52.19492, ...
#         1337820723  POLYGON ((0.13817 52.19348, 0.13844 52.1934, 0...
#         1337820726  POLYGON ((0.13802 52.19357, 0.13809 52.19355, ...
#
#                     addr:city addr:postcode    addr:street   alt_name  \
# element id
# ...

# %% [markdown]
# ### 1.1.5 Map of England

# %% [markdown]
# This dataset is extremely large at 2GB. It takes over an hour to download and to save it into a CSV file. Moreover, the format downloaded has the columns `id`, `latitude`, `longitude` and `tags`, but since all the columns are given to us as keys in the `tags` dictionary, we have to do further processing of data in a DataFrame, yet there is not enough RAM to handle all the data as it is being loaded into the DataFrame.
#
# For now we will download the CSV file, examine the columns, and in 1.2.4 we will download in smaller chunks of DataFrames due to the limited RAM for upload to AWS before we proceed to the next chunk.

# %%
# %pip install osmium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.1 MB/s eta 0:00:00
# ...

# %%
import osmium

# %%
# Download the .osm.pbf file
url = "https://download.openstreetmap.fr/extracts/europe/united_kingdom-latest.osm.pbf"
file_name = "/tmp/united_kingdom-latest.osm.pbf"

response = requests.get(url)
response.raise_for_status()
with open(file_name, "wb") as f:
    f.write(response.content)

print(f"File downloaded and saved as: {file_name}")

# Define the OSMHandler class to process the .osm.pbf file
class OSMHandler(osmium.SimpleHandler):
    def __init__(self):  # Corrected method name from _init_ to __init__
        super().__init__()
        self.data = []  # Initialize the data attribute

    def node(self, n):
        tags = dict(n.tags)
        if tags:
            self.data.append([n.id, n.location.lat, n.location.lon, dict(n.tags)])

# Process the OSM file
print("Processing the file...")
handler = OSMHandler()
handler.apply_file(file_name)

# Save the data to a CSV file
map_df = pd.DataFrame(handler.data, columns=["id", "latitude", "longitude", "tags"])
map_df.to_csv("united_kingdom-latest.csv", index=False)
print("Complete!")
# Out:
# File downloaded and saved as: /tmp/united_kingdom-latest.osm.pbf
# Processing the file...
# Complete!

# %% [markdown]
# Next, we will examine the number of features, as well as the top 80 most important features.

# %%
import ast

# %%
with open("united_kingdom-latest.csv", "r") as file:
    total_rows = sum(1 for _ in file)
total_rows -= 1
total_rows
# Out:
# 8146089

# %%
col = {}
index = 0
chunksize = 1000000
chunks = pd.read_csv("united_kingdom-latest.csv", chunksize=chunksize)
with open("united_kingdom-latest.csv", "r") as file:
    total_rows = sum(1 for _ in file)
total_rows -= 1
for chunk in chunks:
    for tag in chunk["tags"]:
        tag_dict = ast.literal_eval(tag)
        for key in tag_dict:
            col[key] = col.get(key, 0) + 1
    print("Completed rows: {0} to {1}".format(index*chunksize + 1, min((index+1)*chunksize, total_rows)))
    index += 1
print("Final dictionary of tag counts:", col)

# %%
sorted_tags = sorted(col.items(), key=lambda x: x[1], reverse=True)
print("There are", len(col), "features.")
print("The highest feature has", sorted_tags[0][1] / sorted_tags[79][1], "times the frequency of the 100th highest feature.")
# Out:
# There are 8098 features.
# The highest feature has 32.099652159158396 times the frequency of the 100th highest feature.

# %%
import matplotlib.pyplot as plt
tags, counts = zip(*sorted_tags)
plt.figure(figsize=(18, 6))
plt.bar(tags[:80], counts[:80])
plt.xticks(rotation=90)
plt.xlabel('Tags')
plt.ylabel('Frequency')
plt.title('Tag Frequency Distribution (Top 100)')
plt.show()

# %% [markdown]
# Preliminary investigations on the dataset tell me a few problematic things:
#
# 1. There are 8098 columns at the time of upload. It is unwise to upload everything to AWS, especially since we need to deal with formatting when creating tables, which takes far too long. As such, I will upload the first 80 columns. Indeed, the graph above shows that even the highest feature (`power`) has about $10^{-6}$ presence in the dataset, telling me it is very sparse. To save ourselves memory space, it is better to stick with more meaningful data (the top 80 most common features). Moreover, it will help our linear regression model later, since feature vectors that have mostly 0 values act like indicator functions for Output Areas that actually have non-zero values, and since there are few such Output Areas, the model is prone to overfitting to those areas, and the coefficients for those features can have a very high variance. Since the highest `power` has 32 times as much frequency as `historic`, I will prune the columns to the first 80 most common features. (While I am aware some columns do not appear particularly useful, such as `phone` or `ref`, it is important to keep as much data as possible in case I find it useful later. In Data Science, we want to keep our data at our fingertips, as it is wasteful to throw data away as we may need it later, or even for someone else to use.)
#
# 2. Preliminary findings in the CSV file showed me that a large proportion of the table has the tag `{"created_by": "JOSM"}`, which stands for Java Open Street Maps. While such information could be about houses or schools or relevant buildings, the row itself does not give me much information as it is a dictionary with a single field, along with the latitude and longitude. Hence, in 1.2.4, my code discards all such rows and the table produced is much smaller.
#
# 3. There are 8146089 rows in the dataset, excluding the header. This dataset runs out of RAM if it is converted to a DataFrame with 80 columns. There is a need in 1.2.4 to split the dataset into chunks, then upload each DataFrame to AWS, and dropping it before the next chunk is processed.

# %% [markdown]
# Note also that I decided to open the CSV file twice (one for exploring the columns here, and one for uploading to AWS in 1.2.4), because I needed to identify the schema of the database.

# %% [markdown]
# ### 1.2

# %% [markdown]
# Again, we will use the same pandas Dataframes and upload to AWS:
#
# 1. TS062: National Statistics Socio-economic Classification,
# 2. TS037: General Health,
# 3. Geographic Coordinates of Census Output Areas,
#
# and OSM data for
# 4. Map of England.
#
# I will *not* store the tables acquired from the Open Street Maps API Connection since they are coordinates specific and can be searched up in a short time for a 1km x 1km bounding box. Moreover, the features available for each region varies: Cambridge itself has 303 columns. It is not meaningful to upload tables whose features dynamically change for each region.
#
# An adddition thing we will do in this section is **to create indexes for columns that are likely to be joined later**. In particular, we note that the **`geography_code` in `age.csv` and `health.csv`** are likely related to **`latitude` and `longitude` in `united_kingdom-latest.csv`** since we want to relate individual nodes in England to their Output Areas. While the two tables do not share columns, they can be joined on `census_coord`, so we will need to index:
#
# 1. `geography_code` in ns_sec
# 2. `geography_code` in health
# 3. `0a21cd` in `census_coord`
# 4. `lat`, `long` in `census_coord` (as a joint index for calculations)
# 5. `latitude` and `longitude` in `map` (as a joint index for calculations).

# %% [markdown]
# First, we should set up the connection to the AWS database, then we can upload data.

# %%
import yaml
from ipywidgets import interact_manual, Text, Password

# %%
@interact_manual(username=Text(description="Username:"),
                password=Password(description="Password:"),
                url=Text(description="URL:"),
                port=Text(description="Port:"))
def write_credentials(username, password, url, port):
    with open("credentials.yaml", "w") as file:
        credentials_dict = {'username': username,
                           'password': password,
                           'url': url,
                           'port': port}
        yaml.dump(credentials_dict, file)
# Out:
# interactive(children=(Text(value='', description='Username:'), Password(description='Password:'), Text(value='…

# %%
with open("credentials.yaml") as file:
    credentials = yaml.safe_load(file)
    username = credentials["username"]
    password = credentials["password"]
    url = credentials["url"]
    port = credentials["port"]

# %%
# %pip install pymysql
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# %sql mariadb+pymysql://$username:$password@$url?local_infile=1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.1 MB/s eta 0:00:00
# ...

# %%
conn = fynesse.access.create_connection(username, password, url, 'ads_2024', int(port))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-144302cf1388> in <cell line: 1>()
# ----> 1 conn = fynesse.access.create_connection(username, password, url, 'ads_2024', int(port))
#
# NameError: name 'fynesse' is not defined

# %% [markdown]
# ### 1.2.1 TS062: National Statistics Socio-economic Classification

# %%
# %%sql
#
# USE `ads_2024`;
# DROP TABLE IF EXISTS `ns_sec`;
# CREATE TABLE IF NOT EXISTS `ns_sec` (
#     `date` int(10) unsigned NOT NULL,
#     `geography_code` char(9),
#     `ns_sec_total` int(10) unsigned NOT NULL,
#     `ns_sec_l1_l2_l3` int(10) unsigned NOT NULL,
#     `ns_sec_l4_l5_l6` int(10) unsigned NOT NULL,
#     `ns_sec_l7` int(10) unsigned NOT NULL,
#     `ns_sec_l8_l9` int(10) unsigned NOT NULL,
#     `ns_sec_l10_l11` int(10) unsigned NOT NULL,
#     `ns_sec_l12` int(10) unsigned NOT NULL,
#     `ns_sec_l13` int(10) unsigned NOT NULL,
#     `ns_sec_l14_1_l14_2` int(10) unsigned NOT NULL,
#     `ns_sec_l15` int(10) unsigned NOT NULL,
#     `db_id` bigint(20) unsigned NOT NULL
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
#
# ALTER TABLE `ns_sec`
# ADD PRIMARY KEY (`db_id`);
#
# ALTER TABLE `ns_sec`
# MODIFY db_id bigint(20) unsigned NOT NULL AUTO_INCREMENT, AUTO_INCREMENT=1;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# USE `ads_2024`;
# LOAD DATA LOCAL INFILE "./age.csv" INTO TABLE `ns_sec` FIELDS TERMINATED BY ',' OPTIONALLY ENCLOSED by '"' LINES STARTING BY '' TERMINATED BY '\n';
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 188880 rows affected.
# []

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT * FROM ns_sec LIMIT 5;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 5 rows affected.
# [(2021, 'E00000001', 159, 80, 38, 13, 9, 3, 5, 5, 4, 2, 1),
#  (2021, 'E00000003', 222, 96, 58, 8, 26, 2, 5, 2, 5, 20, 2),
#  (2021, 'E00000005', 103, 37, 28, 8, 21, 0, 3, 1, 1, 4, 3),
#  (2021, 'E00000007', 140, 62, 39, 5, 11, 3, 3, 1, 6, 10, 4),
#  (2021, 'E00000010', 170, 34, 45, 17, 27, 7, 10, 14, 11, 5, 5)]

# %%
# %%sql
#
# USE `ads_2024`;
# CREATE INDEX idx_geography_code ON `ns_sec` (geography_code);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ###1.2.2 TS037: General Health

# %%
# %%sql
#
# USE `ads_2024`;
# DROP TABLE IF EXISTS `health`;
# CREATE TABLE IF NOT EXISTS `health` (
#     `date` int(10) unsigned NOT NULL,
#     `geography_code` char(9),
#     `health_total` int(10) unsigned NOT NULL,
#     `very_good_health` int(10) unsigned NOT NULL,
#     `good_health` int(10) unsigned NOT NULL,
#     `fair_health` int(10) unsigned NOT NULL,
#     `bad_health` int(10) unsigned NOT NULL,
#     `very_bad_health` int(10) unsigned NOT NULL,
#     `db_id` bigint(20) unsigned NOT NULL
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
#
# ALTER TABLE `health`
# ADD PRIMARY KEY (`db_id`);
#
# ALTER TABLE `health`
# MODIFY db_id bigint(20) unsigned NOT NULL AUTO_INCREMENT, AUTO_INCREMENT=1;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# USE `ads_2024`;
# LOAD DATA LOCAL INFILE "./health.csv" INTO TABLE `health` FIELDS TERMINATED BY ',' OPTIONALLY ENCLOSED by '"' LINES STARTING BY '' TERMINATED BY '\n';
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 188880 rows affected.
# []

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT * FROM health LIMIT 5;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 5 rows affected.
# [(2021, 'E00000001', 175, 98, 49, 26, 2, 0, 1),
#  (2021, 'E00000003', 256, 146, 92, 15, 1, 2, 2),
#  (2021, 'E00000005', 112, 62, 39, 8, 3, 0, 3),
#  (2021, 'E00000007', 144, 94, 40, 6, 3, 1, 4),
#  (2021, 'E00000010', 174, 73, 74, 21, 6, 0, 5)]

# %%
# %%sql
#
# USE `ads_2024`;
# CREATE INDEX idx_geography_code ON `health` (geography_code);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ### 1.2.3 Geographic Coordinates of Census Output Areas

# %%
# %%sql
#
# USE `ads_2024`;
#
# DROP TABLE IF EXISTS `census_coord`;
#
# CREATE TABLE IF NOT EXISTS `census_coord` (
#     `0a21cd` char(9) NOT NULL,
#     `ls0a21cd` char(9) NOT NULL,
#     `ls0a21nm` varchar(255) NOT NULL,
#     `ls0a21nmw` char(4) NOT NULL,
#     `bng_e` int unsigned NOT NULL,
#     `bng_n` int unsigned NOT NULL,
#     `lat` decimal(9, 6) NOT NULL,
#     `long` decimal(9, 6) NOT NULL,
#     `globalid` char(36) NOT NULL,
#     `geometry` LONGTEXT NOT NULL,
#     `db_id` bigint(20) unsigned NOT NULL
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
#
# ALTER TABLE `census_coord`
# ADD PRIMARY KEY (`db_id`);
#
# ALTER TABLE `census_coord`
# MODIFY db_id bigint(20) unsigned NOT NULL AUTO_INCREMENT, AUTO_INCREMENT=1;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# USE `ads_2024`;
# LOAD DATA LOCAL INFILE "./census_coord.csv" INTO TABLE `census_coord` FIELDS TERMINATED BY ',' OPTIONALLY ENCLOSED by '"' LINES STARTING BY '' TERMINATED BY '\n';
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 188880 rows affected.
# []

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT * FROM `census_coord` LIMIT 5;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 5 rows affected.
# [('E00000001', 'E01000001', 'City of London 001A', '', 532250, 181864, Decimal('51.520200'), Decimal('-0.095230'), '3a44dd3d-5082-4a09-9b9c-3a5fadc811ed', 'POLYGON ((532303.4919999996 181814.1099999994, 532213.3779999996 181846.1919999998, 532194.8990000002 181874.26300000027, 532162.9718000004 181864.00 ... (43 characters truncated) ... 0027, 532248.3943999996 181895.3501999993, 532282.6299999999 181906.49599999934, 532308.875 181914.79700000025, 532303.4919999996 181814.1099999994))', 1),
# ...

# %%
# %%sql
#
# USE `ads_2024`;
# CREATE INDEX idx_0a21cd ON `census_coord` (0a21cd);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# USE `ads_2024`;
# CREATE INDEX idx_lat_long_area ON `census_coord` (lat, `long`);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ### 1.2.4 Map of England
# (Note that this refers to the data acquired in 1.1.5 and *not* 1.1.4.)

# %% [markdown]
# Now, we will create a table with our 100 columns. This is in addition to `id`, `latitude` and `longitude` which was originally present in the CSV file.

# %%
# %%sql
#
# USE ads_2024;
# DROP TABLE IF EXISTS map;
# CREATE TABLE IF NOT EXISTS map (
#     id bigint(20) unsigned NOT NULL,
#     latitude decimal(9, 6) NOT NULL,
#     longitude decimal(9, 6) NOT NULL,
#     power varchar(255) NOT NULL,
#     `natural` varchar(255) NOT NULL,
#     `source` varchar(255) NOT NULL,
#     highway varchar(255) NOT NULL,
#     `name` varchar(255) NOT NULL,
#     barrier varchar(255) NOT NULL,
#     addr_street varchar(255) NOT NULL,
#     amenity varchar(255) NOT NULL,
#     addr_housenumber varchar(255) NOT NULL,
#     created_by varchar(255) NOT NULL,
#     addr_city varchar(255) NOT NULL,
#     generator_source varchar(255) NOT NULL,
#     generator_type varchar(255) NOT NULL,
#     generator_method varchar(255) NOT NULL,
#     generator_output_electricity varchar(255) NOT NULL,
#     location varchar(255) NOT NULL,
#     addr_postcode varchar(255) NOT NULL,
#     direction varchar(255) NOT NULL,
#     naptan_atco_code varchar(255) NOT NULL,
#     public_transport varchar(255) NOT NULL,
#     naptan_common_name varchar(255) NOT NULL,
#     naptan_bearing varchar(255) NOT NULL,
#     crossing varchar(255) NOT NULL,
#     naptan_street varchar(255) NOT NULL,
#     bus varchar(255) NOT NULL,
#     tactile_paving varchar(255) NOT NULL,
#     material varchar(255) NOT NULL,
#     operator varchar(255) NOT NULL,
#     naptan_naptan_code varchar(255) NOT NULL,
#     naptan_verified varchar(255) NOT NULL,
#     naptan_indicator varchar(255) NOT NULL,
#     entrance varchar(255) NOT NULL,
#     ref varchar(255) NOT NULL,
#     leaf_type varchar(255) NOT NULL,
#     shop varchar(255) NOT NULL,
#     generator_solar_modules varchar(255) NOT NULL,
#     naptan_landmark varchar(255) NOT NULL,
#     leaf_cycle varchar(255) NOT NULL,
#     addr_country varchar(255) NOT NULL,
#     traffic_calming varchar(255) NOT NULL,
#     `access` varchar(255) NOT NULL,
#     crossing_island varchar(255) NOT NULL,
#     species varchar(255) NOT NULL,
#     shelter varchar(255) NOT NULL,
#     naptan_plusbus_zone_ref varchar(255) NOT NULL,
#     place varchar(255) NOT NULL,
#     brand varchar(255) NOT NULL,
#     operator_wikidata varchar(255) NOT NULL,
#     brand_wikidata varchar(255) NOT NULL,
#     man_made varchar(255) NOT NULL,
#     denotation varchar(255) NOT NULL,
#     foot varchar(255) NOT NULL,
#     note varchar(255) NOT NULL,
#     crossing_markings varchar(255) NOT NULL,
#     website varchar(255) NOT NULL,
#     kerb varchar(255) NOT NULL,
#     noexit varchar(255) NOT NULL,
#     height varchar(255) NOT NULL,
#     backrest varchar(255) NOT NULL,
#     railway varchar(255) NOT NULL,
#     fhrs_id varchar(255) NOT NULL,
#     tourism varchar(255) NOT NULL,
#     bench varchar(255) NOT NULL,
#     bicycle varchar(255) NOT NULL,
#     check_date varchar(255) NOT NULL,
#     site_name varchar(255) NOT NULL,
#     plot_number varchar(255) NOT NULL,
#     ward varchar(255) NOT NULL,
#     constituency varchar(255) NOT NULL,
#     ref_usrn varchar(255) NOT NULL,
#     covered varchar(255) NOT NULL,
#     age varchar(255) NOT NULL,
#     height_range varchar(255) NOT NULL,
#     capacity varchar(255) NOT NULL,
#     post_box_type varchar(255) NOT NULL,
#     tree_form varchar(255) NOT NULL,
#     opening_hours varchar(255) NOT NULL,
#     survey_date varchar(255) NOT NULL,
#     phone varchar(255) NOT NULL,
#     local_ref varchar(255) NOT NULL,
#     royal_cypher varchar(255) NOT NULL,
#     db_id bigint(20) unsigned NOT NULL
# ) DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1;
#
# ALTER TABLE map
# ADD PRIMARY KEY (db_id);
#
# ALTER TABLE map
# MODIFY db_id bigint(20) unsigned NOT NULL AUTO_INCREMENT, AUTO_INCREMENT=1;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# We cannot directly call `LOAD DATA LOCAL INFILE` on our dataset because there are only four columns in the CSV file and we need to process it first. But we also cannot use a DataFrame for all the CSV data because we will run out of RAM. To address this, we will create smaller DataFrames per 200000 rows of data, then upload each CSV file to AWS one by one.

# %%
import gc
import ast
import pandas as pd
import requests

# %%
import pandas as pd
import numpy as np
import ast
import gc

def process_chunk(file_path, tags, i, chunksize, total_rows):

    skip_rows = range(1, (i - 1) * chunksize + 1)
    chunk = pd.read_csv(file_path, skiprows=skip_rows, nrows=chunksize)
    chunk = chunk[chunk["tags"] != "{'created_by': 'JOSM'}"]
    rows = []

    for _, row in chunk.iterrows():
        tag = row["tags"]
        tag_dict = ast.literal_eval(tag)
        new_dict = {'id': row["id"], 'latitude': row["latitude"], 'longitude': row["longitude"]}
        new_dict.update({feature: np.nan for feature in tags[:80]})
        for key in tag_dict:
            new_dict[key] = tag_dict[key]
        rows.append(new_dict)

    output_file = f"map-part-{i}.csv"
    df = pd.DataFrame(rows)
    df.to_csv(output_file, index=False, header=False)

    load_query = f"""
    LOAD DATA LOCAL INFILE '{output_file}'
    INTO TABLE `map`
    FIELDS TERMINATED BY ','
    OPTIONALLY ENCLOSED BY '"'
    LINES TERMINATED BY '\\n';
    """
    # %sql USE `ads_2024`
    # %sql {load_query}

    print("Completed rows: {0} to {1} ({2:.2f}%)".format(
        (i - 1) * chunksize + 1,
        min(i * chunksize, total_rows),
        min(i * chunksize, total_rows) / total_rows * 100
    ))

    del df
    gc.collect()

file_path = "united_kingdom-latest.csv"
chunksize = 100000
num_chunks = (total_rows // chunksize) + (1 if total_rows % chunksize > 0 else 0)
num_chunks
# Out:
# 82

# %% [markdown]
# There are 82 chunks present, so we will load them chunk by chunk into AWS.

# %%
for i in range(1, num_chunks + 1):
    process_chunk(file_path, tags, i, chunksize, total_rows)
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 77603 rows affected.
# Completed rows: 1 to 100000 (1.23%)
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 73734 rows affected.
# Completed rows: 100001 to 200000 (2.46%)
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 35997 rows affected.
# Completed rows: 200001 to 300000 (3.68%)
# ...

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT * FROM `map` LIMIT 5;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 5 rows affected.
# [(129, Decimal('53.959357'), Decimal('-1.081517'), '', '', '', '', 'Vodafone', '', 'Parliament Street', '', '29-30', '', 'York', '', '', '', '', '', 'YO1 8RS', '', '', '', '', '', '', '', '', '', '', 'Vodafone Limited', '', '', '', '', '', '', 'mobile_phone', '', '', '', '', '', '', '', '', '', '', '', 'Vodafone', '', 'Q122141', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '2016-02-19', '', '', '', '', '', '', '', '', '', '', '', 'Mo-Sa 09:00-17:30; Su 10:30-16:30', '', '', '', 'York - Parliament Street', 1),
# ...

# %% [markdown]
# The table is sparse, as expected.

# %%
# %sql USE `ads_2024`;
final_rows = %sql SELECT COUNT(*) FROM `map`
final_rows[0][0]/total_rows
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 1 rows affected.
# 0.9409651674564321

# %% [markdown]
# It also appears that our database uploaded when removing `{"created_by": "JOSM"}`, we managed to remove an entire 6% of redundant data, which is about 120MB. This will save us some time during our queries later.

# %%
# %%sql
# USE `ads_2024`;
# CREATE INDEX idx_lat_long ON `map` (latitude, longitude);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# Write a short paragraph summarising what you did in the Access stage.

# %% [markdown]
# In conclusion, we downloaded Census Data, Geographic Coordinates of Census Output Areas, the Map of England and saved it to the AWS database. We also set up an API connection to OSM so we can use a bounding box to retrieve features in an area, that we can use as feature vectors in our linear regression model later.

# %% [markdown]
# ## Assess

# %% [markdown]
# Let us refer back to the overarching project question: how can we predict the proportion of L15 students in each Output Area from OSM features?

# %% [markdown]
# ### Response Vector
#
# The response vector is easily manipulated, we can simply use `ns_sec` to retrieve the information as it is already nicely formatted for us.

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT * FROM ns_sec LIMIT 5;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 5 rows affected.
# [(2021, 'E00000001', 159, 80, 38, 13, 9, 3, 5, 5, 4, 2, 1),
#  (2021, 'E00000003', 222, 96, 58, 8, 26, 2, 5, 2, 5, 20, 2),
#  (2021, 'E00000005', 103, 37, 28, 8, 21, 0, 3, 1, 1, 4, 3),
#  (2021, 'E00000007', 140, 62, 39, 5, 11, 3, 3, 1, 6, 10, 4),
#  (2021, 'E00000010', 170, 34, 45, 17, 27, 7, 10, 14, 11, 5, 5)]

# %% [markdown]
# With a bit of data manipulation, we can see that L15 proportion is just L15 divided by total population.

# %%
# %%sql
#
# USE `ads_2024`;
# DROP TABLE IF EXISTS ns_sec_prop;
# CREATE TABLE IF NOT EXISTS ns_sec_prop AS
# SELECT geography_code,
#        ns_sec_l15/ns_sec_total AS prop_l15,
#        db_id
# FROM ns_sec;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 188880 rows affected.
# []

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT * from ns_sec_prop LIMIT 5;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 5 rows affected.
# [('E00000001', Decimal('0.0126'), 1),
#  ('E00000003', Decimal('0.0901'), 2),
#  ('E00000005', Decimal('0.0388'), 3),
#  ('E00000007', Decimal('0.0714'), 4),
#  ('E00000010', Decimal('0.0294'), 5)]

# %% [markdown]
# ### Feature Vectors

# %% [markdown]
# Next, we explore the OSM data, and the columns that are relevant. **The ultimate goal is to transform the OSM data into feature vectors**, with each element describing some numeric value of the Output Area. If we were to look at the DataFrame we downloaded earlier:

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT * FROM census_coord LIMIT 5;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 5 rows affected.
# [(1, 'E00000001', 'E01000001', 'City of London 001A', '', 532250, 181864, Decimal('51.520220'), Decimal('-0.095230'), Decimal('6949.151482'), Decimal('421.166161'), '3a44dd3d-5082-4a09-9b9c-3a5fadc811ed', 1, 0.622238, 0.782828, 0.999999, -0.00166208, 83.3616),
#  (2, 'E00000003', 'E01000001', 'City of London 001A', '', 532171, 181819, Decimal('51.519830'), Decimal('-0.096380'), Decimal('4492.411072'), Decimal('307.714653'), 'f1216dc8-14d1-4857-9230-cab0641758fb', 2, 0.622244, 0.782824, 0.999999, -0.00168215, 67.0255),
#  (3, 'E00000005', 'E01000001', 'City of London 001A', '', 532166, 181722, Decimal('51.518960'), Decimal('-0.096490'), Decimal('8565.514214'), Decimal('385.204781'), '44d6f70f-549c-4288-9b6d-de2adbf02582', 3, 0.622256, 0.782814, 0.999999, -0.00168407, 92.5501),
# ...

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT * FROM map LIMIT 5;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 5 rows affected.
# [(129, Decimal('53.959357'), Decimal('-1.081517'), '', '', '', '', 'Vodafone', '', 'Parliament Street', '', '29-30', '', 'York', '', '', '', '', '', 'YO1 8RS', '', '', '', '', '', '', '', '', '', '', 'Vodafone Limited', '', '', '', '', '', '', 'mobile_phone', '', '', '', '', '', '', '', '', '', '', '', 'Vodafone', '', 'Q122141', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '2016-02-19', '', '', '', '', '', '', '', '', '', '', '', 'Mo-Sa 09:00-17:30; Su 10:30-16:30', '', '', '', 'York - Parliament Street', 1, 0.588359, 0.8086, 0.999822, -0.0188749),
# ...

# %% [markdown]
# An immediate problem is that `latitude`s and `longitude`s are supposed to be joined, since we want to know for each `node` in `map` which output area (`0a21cd`) it maps to. Unfortunately, `latitude`s and `longitudes` are rounded to the nearest 6 decimal places, which gives us an extremely low chance of maps. Moreover, in `census_coord` we are not given enough information about the geometries -- all we have are `shape_area` and `shape_length` (i.e. area or perimeter).
#
# To resolve this, the metric I will use to joining is to compare each `node` in `map` to all the `lat` and `long` in `census_coord` by **distance from Output Areas divided by its radius**. That is,
#
# $$\text{Output Area of node} = \text{argmin}_{\text{Output Area}} \frac{\text{distance from Output Area}}{\text{radius of Output Area}}$$
#
# The argument for this is as follows. We assume each (lat, long) refers to the center of the output area, then we want the output area which minimises the distance of that node from the center as it is most *likely* to contain the node. However, if there is a node that is 2km from output area A and 3km from output area B, a naive model that finds the minimum distance will instantly classify the node to A, yet A could have a smaller area that extends its outskirts to 1km, and B to 4km, so theoretically the node should be classified in B. This equation (while just an approximation) hence **normalises** distances with respect to the actual areas of Output Areas, making it a fairer comparison (in the example above, comparing 2 to 0.75 shows output area B is clearly the better choice).
#
# To save ourselves from extreme computational power having to calculate the Haversine distance at for every row in the `CROSS JOIN`, we will extend both tables to include the cosine and sine, as well as the radius (proportional to squareroot of area).

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT * FROM census_coord LIMIT 5;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 5 rows affected.
# [(1, 'E00000001', 'E01000001', 'City of London 001A', '', 532250, 181864, Decimal('51.520220'), Decimal('-0.095230'), Decimal('6949.151482'), Decimal('421.166161'), '3a44dd3d-5082-4a09-9b9c-3a5fadc811ed', 1, 0.622238, 0.782828, 0.999999, -0.00166208, 83.3616),
#  (2, 'E00000003', 'E01000001', 'City of London 001A', '', 532171, 181819, Decimal('51.519830'), Decimal('-0.096380'), Decimal('4492.411072'), Decimal('307.714653'), 'f1216dc8-14d1-4857-9230-cab0641758fb', 2, 0.622244, 0.782824, 0.999999, -0.00168215, 67.0255),
#  (3, 'E00000005', 'E01000001', 'City of London 001A', '', 532166, 181722, Decimal('51.518960'), Decimal('-0.096490'), Decimal('8565.514214'), Decimal('385.204781'), '44d6f70f-549c-4288-9b6d-de2adbf02582', 3, 0.622256, 0.782814, 0.999999, -0.00168407, 92.5501),
# ...

# %%
# %%sql
#
# USE `ads_2024`;
#
# ALTER TABLE census_coord
# ADD COLUMN cos_lat FLOAT,
# ADD COLUMN sin_lat FLOAT,
# ADD COLUMN cos_long FLOAT,
# ADD COLUMN sin_long FLOAT,
# ADD COLUMN sqrt_shape_area FLOAT;
#
# ALTER TABLE map
# ADD COLUMN cos_lat FLOAT,
# ADD COLUMN sin_lat FLOAT,
# ADD COLUMN cos_long FLOAT,
# ADD COLUMN sin_long FLOAT;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# USE `ads_2024`;
#
# UPDATE census_coord
# SET
#     cos_lat = COS(RADIANS(lat)),
#     sin_lat = SIN(RADIANS(lat)),
#     cos_long = COS(RADIANS(`long`)),
#     sin_long = SIN(RADIANS(`long`)),
#     sqrt_shape_area = SQRT(shape_area);
#
# UPDATE map
# SET
#     cos_lat = COS(RADIANS(latitude)),
#     sin_lat = SIN(RADIANS(latitude)),
#     cos_long = COS(RADIANS(longitude)),
#     sin_long = SIN(RADIANS(longitude));
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 188880 rows affected.
# 7665186 rows affected.
# []

# %%
# %%sql
# USE `ads_2024`;
#
# CREATE INDEX IF NOT EXISTS idx_cos_lat ON census_coord(cos_lat);
# CREATE INDEX IF NOT EXISTS idx_sin_lat ON census_coord(sin_lat);
# CREATE INDEX IF NOT EXISTS idx_cos_long ON census_coord(cos_long);
# CREATE INDEX IF NOT EXISTS idx_sin_long ON census_coord(sin_long);
# CREATE INDEX IF NOT EXISTS idx_sqrt_shape_area ON census_coord(sqrt_shape_area);
#
# CREATE INDEX IF NOT EXISTS idx_cos_lat_map ON map(cos_lat);
# CREATE INDEX IF NOT EXISTS idx_sin_lat_map ON map(sin_lat);
# CREATE INDEX IF NOT EXISTS idx_cos_long_map ON map(cos_long);
# CREATE INDEX IF NOT EXISTS idx_sin_long_map ON map(sin_long);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_44955/1765862310.py in <cell line: 1>()
# ...

# %%
# %%sql
#
# USE `ads_2024`;
# SHOW PROCESSLIST;

# %%
# %%sql
#
# WITH distcalc AS (
#     SELECT
#         census_coord.db_id AS cdbid,
#         map.db_id AS mdbid,
#         SQRT(POW(census_coord.lat - map.latitude, 2) + POW(census_coord.`long` - map.longitude, 2)) AS `norm_distance`
#     FROM census_coord
#     JOIN (SELECT * FROM map LIMIT 10000) as map
#         ON map.latitude BETWEEN census_coord.lat - 0.1 AND census_coord.lat + 0.1
#         AND map.longitude BETWEEN census_coord.long - 0.1 AND census_coord.long + 0.1
# )
# SELECT distcalc.cdbid, distcalc.mdbid, MIN(norm_distance) AS min_distance
# FROM distcalc
# GROUP BY mdbid;

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT COUNT(`power`) FROM map limit 5;

# %%
# %%sql
#
# USE `ads_2024`;
#
# WITH distcalc AS (
#     SELECT
#         census_coord.0a21cd AS 0a21cd,
#         census_coord.db_id AS cdbid,
#         census_coord.lat AS lat1,
#         census_coord.long AS long1,
#         map.db_id AS mdbid,
#         map.latitude AS lat2,
#         map.longitude AS long2,
#         6371 * ACOS(
#             COS(RADIANS(census_coord.lat)) * COS(RADIANS(map.latitude)) *
#             COS(RADIANS(map.longitude) - RADIANS(census_coord.long)) +
#             SIN(RADIANS(census_coord.lat)) * SIN(RADIANS(map.latitude))
#         ) AS distance
#     FROM census_coord
#     JOIN map
#     ON 6371 * ACOS(
#             COS(RADIANS(census_coord.lat)) * COS(RADIANS(map.latitude)) *
#             COS(RADIANS(map.longitude) - RADIANS(census_coord.long)) +
#             SIN(RADIANS(census_coord.lat)) * SIN(RADIANS(map.latitude))
#         ) = (
#             SELECT MIN(6371 * ACOS(
#                 COS(RADIANS(census_coord.lat)) * COS(RADIANS(map.latitude)) *
#                 COS(RADIANS(map.longitude) - RADIANS(census_coord.long)) +
#                 SIN(RADIANS(census_coord.lat)) * SIN(RADIANS(map.latitude))
#             ))
#             FROM map
#         )
# )
# SELECT *
# FROM distcalc LIMIT 5;

# %%
# %%sql
#
# USE `ads_2024`;
#
# WITH DistanceCalc AS (
#     SELECT
#         c.0a21cd AS 0a21cd,
#         m.id AS id,
#         c.lat AS lat1,
#         c.long AS long1,
#         m.latitude AS lat2,
#         m.longitude AS long2,
#         6371 * ACOS(
#             COS(RADIANS(c.lat)) * COS(RADIANS(m.latitude)) *
#             COS(RADIANS(m.longitude) - RADIANS(c.long)) +
#             SIN(RADIANS(c.lat)) * SIN(RADIANS(m.latitude))
#         ) AS distance
#     FROM census_coord c
#     CROSS JOIN map m
# )
# SELECT
#     dc.0a21cd,
#     dc.distance
# FROM DistanceCalc dc
# JOIN (
#     SELECT dc.0a21cd, MIN(dc.distance) AS min_distance
#     FROM DistanceCalc dc
#     GROUP BY dc.0a21cd
# ) AS closest ON dc.0a21cd = closest.0a21cd AND dc.distance = closest.min_distance;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# KeyboardInterrupt

# %%
# %%sql
#
# USE `ads_2024`;
# SELECT
#     fid,
#     0a21cd,
#     ls0a21cd,
#     ls0a21nm,
#     lat,
#     `long`,
#     shape_area,
#     shape_length,
#     globalid,
#     db_id,
#     (6371 * acos(
#         cos(radians(51.520220)) * cos(radians(lat)) *
#         cos(radians(`long`) - radians(0.000000)) +
#         sin(radians(51.520220)) * sin(radians(lat))
#     )) AS distance
# FROM
#     census_coord
# WHERE
#     lat IS NOT NULL AND `long` IS NOT NULL
# ORDER BY
#     distance,
#     shape_area DESC  -- Prioritize large areas closer to the point
# LIMIT 100;

# %%
len(osmnx_df.columns.values) #CHANGE TO MAP_OUTPUT_DF
# Out:
# 303

# %% [markdown]
# There is quite a lot to change in the data. Let us do a step by step transformation for this dataset into a design matrix.
#
# 1. There are a lot of NaN values, and it is unlikely that we have enough training data if our feature vectors are sparse.
# 2. Not all cell values are numeric. To adjust this to a feature vector, one can count the occurrences of given features (e.g. count the number of rows with `osmnx_df[osmnx_df["amenity"]=="university"]` for each Output Area.
# 3.
#
# It will be very foolish to investigate manually each of the 303 columns if they are correlated to L15 population, and even if so, it would be unwise to investigate the extent of correlation.
#
# Our solution here will be twofold. Firstly, we will try to eliminate columns with many NaN values, since it is unlikely that we have enough training data if our feature vectors are sparse. Secondly, we will use a feature correlation matrix to see

# %% [markdown]
# ### There are a lot of NaN values.
#
# The sparse dataset has ___ columns, yet many of them have NaN values -- it is likely that they were shown once by some node, included in the column list, and therefore does not provide any meaningful insights to a majority of nodes. Hence, we will eliminate columns with NaN values spanning more than 99% of the dataset.

# %%
proportion_nan = osmnx_df.isna().mean()
osmnx_cleaned = osmnx_df.loc[:, proportion_nan < 0.99]
osmnx_cleaned
# Out:
#                                                              geometry  \
# element id
# node    20823646                             POINT (0.12613 52.20262)
#         20823709                             POINT (0.13055 52.20086)
#         20823843                             POINT (0.13038 52.20478)
#         20826694                             POINT (0.13919 52.20238)
#         20826702                             POINT (0.13885 52.19961)
# ...                                                               ...
# way     1337666662  POLYGON ((0.13464 52.1874, 0.13528 52.18621, 0...
#         1337672054  POLYGON ((0.13089 52.18904, 0.1313 52.18913, 0...
#         1337674625  POLYGON ((0.12259 52.19495, 0.12261 52.19492, ...
#         1337820723  POLYGON ((0.13817 52.19348, 0.13844 52.1934, 0...
#         1337820726  POLYGON ((0.13802 52.19357, 0.13809 52.19355, ...
#
#                     addr:city addr:postcode    addr:street     amenity  \
# element id
# ...

# %% [markdown]
# A caveat here: a correlation matrix identifies **linear relationships** between features and the response (e.g. if $y$ is linearly related to $e^{x_1}$, then the correlation score between $y$ and $x_1$ may be less than ideal.

# %%
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine
import psycopg2

# 1. Pull the OA boundary data and ns_sec data from the AWS SQL database
connection_string = f"mariadb+pymysql://{username}:{password}@{url}/ads_2024?local_infile=1"

# Connect to the AWS database (Replace with your connection details)
engine = create_engine(connection_string)

# Load the OA boundary data
oa_query = "SELECT * FROM census_coord"
oa_boundaries_df = pd.read_sql(oa_query, engine)

# Load the ns_sec data
ns_sec_query = "SELECT * FROM ns_sec"
ns_sec_data_df = pd.read_sql(ns_sec_query, engine)

# Convert OA boundaries to a GeoDataFrame
# Assuming the `geometry` column has well-defined lat/long points (update column names as needed)
oa_boundaries = gpd.GeoDataFrame(oa_boundaries_df, geometry=gpd.points_from_xy(oa_boundaries_df['long'], oa_boundaries_df['lat']))

# 2. Filter the OSMnx data for university buildings
# Assuming you already have the OSMnx data in a DataFrame `osmnx_data`
# Make sure to filter for university buildings
university_buildings = osmnx_df[osmnx_df['amenity'] == 'university']

# 3. Convert both OSMnx and OA boundary data to GeoDataFrames if they are not already
# Assuming OSMnx data is already in a DataFrame with coordinates in 'LONG' and 'LAT'

# Step 1: Extract longitude and latitude from the 'geometry' column if it's stored as (longitude, latitude)
university_buildings['longitude'] = university_buildings['geometry'].apply(lambda x: x[0] if isinstance(x, tuple) else None)
university_buildings['latitude'] = university_buildings['geometry'].apply(lambda x: x[1] if isinstance(x, tuple) else None)

# Step 2: Create a GeoDataFrame with the extracted coordinates using points_from_xy
osmnx_geo = gpd.GeoDataFrame(university_buildings, geometry=gpd.points_from_xy(university_buildings['longitude'], university_buildings['latitude']))

# Step 3: Verify the GeoDataFrame


# 4. Ensure both GeoDataFrames have the same CRS (Coordinate Reference System)
# Set CRS for the OA boundaries GeoDataFrame if it doesn't have one, e.g., WGS84 (EPSG:4326)
oa_boundaries = oa_boundaries.set_crs('EPSG:4326', allow_override=True)
osmnx_geo = osmnx_geo.set_crs('EPSG:4326', allow_override=True)

# 5. Perform a spatial join to link university buildings with output areas
joined = gpd.sjoin(osmnx_geo, oa_boundaries, how="inner", predicate="intersects")
print(repr(joined.columns))
# 6. Count the number of university buildings per output area
building_counts = joined.groupby("oa21cd").size().reset_index(name="university_count")

# 7. Merge the counts back into the output areas dataframe (optional)
oa_with_counts = oa_boundaries.merge(building_counts, on="oa21cd", how="left").fillna(0)

# 8. View the results
print(oa_with_counts[['OA21CD', 'university_count']])

# %%
# %%sql
#
# USE `ads_2024`;
#
# ALTER TABLE census_coord
#     DROP COLUMN cos_lat,
#     DROP COLUMN sin_lat,
#     DROP COLUMN cos_long,
#     DROP COLUMN sin_long,
#     DROP COLUMN sqrt_shape_area;
#
# ALTER TABLE map
#     DROP COLUMN cos_lat,
#     DROP COLUMN sin_lat,
#     DROP COLUMN cos_long,
#     DROP COLUMN sin_long;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ### Attempt 2
#
# We will import individual features from `map` into a GeoDataFrame, and perform a spatial join of it with `census_coord` in a GeoDataFrame. Then, we will join it with `ns_sec_prop`'s `geography_code` so the feature vector follows the ordering in the response vector.

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
from shapely.wkt import loads
from pyproj import CRS, Transformer

# %%
# %sql USE `ads_2024`;
amenity = %sql SELECT latitude, longitude, amenity FROM map WHERE amenity <> '';
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 620929 rows affected.

# %% [markdown]
# We require each node from `map` to have a geometry of POINT(x, y) and each output area in `census_coord` to have a geometry of POLYGON(...), so we can perform a spatial join. While POLYGON(...) is given in `census_coord`, POINT(x, y) is **not** given in `map` -- only the latitudes and longitudes are. This is in the WGS84 coordinate system, so we must transform this to the British National Grid (BNG) system.

# %%
amenity_df = gpd.GeoDataFrame(amenity)

wgs84 = CRS.from_epsg(4326)
bng = CRS.from_epsg(27700)
transformer = Transformer.from_crs(wgs84, bng)

amenity_df[['easting', 'northing']] = amenity_df.apply(
    lambda row: pd.Series(transformer.transform(row['latitude'], row['longitude'])),
    axis=1
)

amenity_df["geometry"] = amenity_df.apply(lambda row: Point(row["easting"], row["northing"]), axis=1)
amenity_df
# Out:
# <ipython-input-104-3540a6398b37>:15: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   amenity_df["geometry"] = amenity_df.apply(lambda row: Point(row["easting"], row["northing"]), axis=1)
#          latitude  longitude          amenity        easting       northing  \
# 0       51.524364  -0.152817     waste_basket  528245.066962  182222.445144
# 1       51.529125  -0.093388   bicycle_rental  532353.824142  182857.630480
# 2       51.528262  -0.143121           advice  528906.674170  182672.942310
# 3       51.534249  -0.140268  bicycle_parking  529087.645573  183343.746771
# ...

# %%
# %sql USE `ads_2024`;
census_coord = %sql SELECT * FROM census_coord;
census_df = gpd.GeoDataFrame(census_coord)
census_df["geometry"] = census_df["geometry"].apply(loads)
census_df
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 188880 rows affected.
#            0a21cd   ls0a21cd              ls0a21nm ls0a21nmw   bng_e   bng_n  \
# 0       E00000001  E01000001   City of London 001A            532250  181864
# 1       E00000003  E01000001   City of London 001A            532171  181819
# 2       E00000005  E01000001   City of London 001A            532166  181722
# 3       E00000007  E01000001   City of London 001A            532088  181473
# 4       E00000010  E01000003   City of London 001C            532092  182114
# ...           ...        ...                   ...       ...     ...     ...
# 188875  W00010693  W01000062          Gwynedd 001A      Gwyn  257885  371596
# 188876  W00010694  W01000645  Carmarthenshire 006C       Sir  240146  220834
# ...

# %%
census_gdf = gpd.GeoDataFrame(census_df, geometry='geometry', crs="EPSG:4326")
amenity_gdf = gpd.GeoDataFrame(amenity_df, geometry='geometry', crs="EPSG:4326")
joined_gdf = gpd.sjoin(amenity_gdf, census_gdf, how="inner", predicate="within")
joined_gdf
# Out:
#          latitude  longitude          amenity        easting       northing  \
# 0       51.524364  -0.152817     waste_basket  528245.066962  182222.445144
# 1       51.529125  -0.093388   bicycle_rental  532353.824142  182857.630480
# 2       51.528262  -0.143121           advice  528906.674170  182672.942310
# 3       51.534249  -0.140268  bicycle_parking  529087.645573  183343.746771
# 4       51.024400  -0.869706          parking  479368.359866  125610.954936
# ...           ...        ...              ...            ...            ...
# 620921  51.423508   0.383032            bench  565780.413127  172082.382970
# 620922  52.030617  -1.315109          parking  447084.011437  237133.116899
# 620923  51.284556  -0.763200  bicycle_parking  486351.457150  154661.412326
# 620924  51.436294  -2.618588            bench  357097.801169  170992.319339
# 620925  51.285285  -0.763485  bicycle_parking  486330.216754  154742.147444
#
# ...

# %%
joined_df = pd.DataFrame(joined_gdf)
counts = joined_df['0a21cd'].value_counts().reset_index()
counts.columns = ['0a21cd', 'count']  # Rename columns for clarity
counts
# Out:
#            0a21cd  count
# 0       E00166755    605
# 1       E00123722    470
# 2       E00170123    438
# 3       E00186781    420
# 4       E00105904    389
# ...           ...    ...
# 105977  E00070109      1
# 105978  E00086441      1
# 105979  E00116682      1
# 105980  E00116677      1
# 105981  E00144837      1
#
# [105982 rows x 2 columns]

# %% [markdown]
# Now that we have our merged table, we will call again `ns_sec_prop` so that we can align the counts of each amenity with each output area.

# %%
# %sql USE `ads_2024`;
response_df = %sql SELECT * FROM ns_sec_prop
response_df = pd.DataFrame(response_df)
response_df
# Out:
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-cyl68.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 188880 rows affected.
#        geography_code prop_l15   db_id
# 0           E00000001   0.0126       1
# 1           E00000003   0.0901       2
# 2           E00000005   0.0388       3
# 3           E00000007   0.0714       4
# 4           E00000010   0.0294       5
# ...               ...      ...     ...
# 188875      W00010693   0.9254  188876
# 188876      W00010694   0.0724  188877
# 188877      W00010695   0.0390  188878
# 188878      W00010696   0.0455  188879
# 188879      W00010697   0.0372  188880
#
# [188880 rows x 3 columns]

# %%
feature_df = pd.merge(response_df, counts, left_on='geography_code', right_on='0a21cd', how='left')
new_feature_df = feature_df.drop(columns=['0a21cd', 'prop_l15', 'db_id'])
new_feature_df['count'] = new_feature_df['count'].fillna(0).astype(int)
new_feature_df
# Out:
#        geography_code  count
# 0           E00000001      2
# 1           E00000003      0
# 2           E00000005      1
# 3           E00000007     46
# 4           E00000010      6
# ...               ...    ...
# 188875      W00010693      7
# 188876      W00010694      1
# 188877      W00010695      0
# 188878      W00010696      0
# 188879      W00010697      0
#
# [188880 rows x 2 columns]

# %% [markdown]
# Write a short paragraph summarising what you did in the Assess stage.

# %%
# TODO: your answer here

# %% [markdown]
# ## Address

# %%
def estimate_students(latitude: float, longitude: float) -> float:
    """
    Args:
    latitude (float): The latitude coordinate.
    longitude (float): The longitude coordinate.

    Returns:
    float: Estimated share of students in that area (value between 0 and 1).
    """
    # TODO: implement
    return NotImplementedError


def estimate_something(latitude: float, longitude: float) -> float:
    #TODO: rename function
    """
    Args:
    latitude (float): The latitude coordinate.
    longitude (float): The longitude coordinate.

    Returns:
    float: Estimated value, percentage, probability, etc
    """
    # TODO: implement
    return NotImplementedError

# %% [markdown]
# Write a short paragraph summarising what you did in the Address stage.

# %%
# TODO: your answer here

# %% [markdown]
# ## Discussion

# %% [markdown]
# #### Story and structure

# %%
# Marks awarded for inline explanation and structure, no need for answers here. Go over your notebook to make sure you explain what you did and why.

# %% [markdown]
# #### Design decisions

# %%
# TODO: your answer here

# %% [markdown]
# #### Comparison

# %%
# TODO: your answer here

# %% [markdown]
# #### Reusability

# %%
# TODO: your answer here

# %% [markdown]
# # Task 2: miniproject (13 marks)

# %% [markdown]
# We expect your miniproject to be more advanced than the example project, and that's why we allocated more marks to it. The first 7 marks will be allocated similarly to Task 1.
#
# 6 remaining points are *bonus* - they will be allocated for going far beyond what you did in Task 1, either in data access, assess, address or story.

# %% [markdown]
# #### Choosing your topic
#
# You are given a lot of flexibility in choosing a miniproject topic.
#
# Some hints:
# - Your project should be based on the Census, Price Paid, OSM and Election datasets.
# - It's a good idea to pick something that you are interested in.
# - Bear in mind there are no marks dedicated to your overall prediction accuracy, so there is no advantage to picking 'easy' topics. It is perfectly ok to not reach significant predictive power, as long as you followed the proper process.
#
# Some guidelines:
# - Do not make a miniproject that furthers discriminatory rhetoric. In general, avoid topics that could be insensitive. If in doubt, message Radzim Sendyka (and *cc* Christian Cabrera) to discuss if this applies to your idea.
# - Please avoid any projects that would require approval from the ethics comittee.
# - Pick the scope of your projects that will allow you to show your skills. Some projects might not be challenging enough while others might be hard to make any progress in. Don't be scared to report negative results.
#
# Please email Radzim Sendyka (and *cc* Christian Cabrera) with your project idea when you begin working on it, so we can let you know about any potential concerns (eg. potentially insensive, too off-topic, too simple, too complex) as soon as we can. You can change the topic up to the submission deadline, but let us know again in cases of major changes.

# %% [markdown]
# Most of the advice from Task 1 still applies, particularly around using an online relational database, structuring your notebook, fynesse, access-assess-address, data readiness levels, hints.

# %% [markdown]
# Sources you may want to include in your data include:
#
#   - UK Census Data
#     - UK Census 2021 data [here](https://www.ons.gov.uk/search?topics=9731,6646,3845,9497,4262,4128,7755,4994,6885,9724,7367&filter=datasets) or [here](https://www.nomisweb.co.uk/sources/census_2021_bulk).
#     - Historical Census data [here](https://www.ons.gov.uk/census/historiccensusdata).
#     - Geographic coordinates of Census Output Areas [here](https://www.data.gov.uk/dataset/4d4e021d-fe98-4a0e-88e2-3ead84538537/output-areas-december-2021-boundaries-ew-bgc-v2).
#   - Spatial data
#     - You should already have a connection to OpenStreetMaps.
#     - You might want to also download the entire map for England (or more) [here](https://download.openstreetmap.fr/extracts/) or [here](https://wiki.openstreetmap.org/wiki/Planet.osm).
#   - Election data
#     - Recent Election Results data [here](https://commonslibrary.parliament.uk/research-briefings/cbp-10009/)
#     - Historical Election Results data [here](https://commonslibrary.parliament.uk/research-briefings/cbp-8647/#fullreport).
#     - Lookup reference between Output Areas and Parliamentary Constituencies [here](https://geoportal.statistics.gov.uk/datasets/5968b5b2c0f14dd29ba277beaae6dec3_0/explore).
#   - Price Paid Data
#     - You should have this data already in your database.
#   - OSM
#     - You should know how to access this data from previous practicals.

# %% [markdown]
# Example ideas:
#
# - Are areas correlated in terms of census results? If so, find the areas that are leading change, and the ones that are following.
# - Which historical census variables used to predict election results in the past, but don't seem related anymore?
# - Census results are only updated once a decade, but new roads and houses are built every year. Can census results, for example those relating to travel, be predicted from basic map information, such as street networks?
# - Building new houses is our best way of tackling the housing crisis. Use the information on new builds in the house prices dataset to explore what factors drive new developments, and make predictions for where the next houses will be built.
# - House styles differ a lot between regions and inhabitants. Can you make any predictions about the house or area simply from looking at it's geometric shape and orientation?
#
# Note that the ideas are just a starting point question. You should include more in-depth investigations into the data, validate your findings where applicable, and prepare visualisations.

# %% [markdown]
# ## Title and description

# %%
# TODO: title your miniproject

# %%
# TODO: provide a very brief description of the goals of your miniproject

# %% [markdown]
# ## TODO: Your Project Goes Here

# %%
import requests

# Overpass API URL for OpenHistoricalMap (OHM)
overpass_url = "http://overpass-api.de/api/interpreter"

# Define the Overpass query for the year 1975
query = """
[out:json];
nwr["amenity"="theatre"]["start_date"](if:
  t["start_date"] < "1976" &&
  (!is_tag("end_date") || t["end_date"] >= "1975"));
out geom;
"""

# Send the request to the Overpass API
response = requests.get(overpass_url, params={'data': query})

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    print(f"Retrieved {len(data['elements'])} nodes/ways/relations.")
else:
    print(f"Error: {response.status_code}")

# Optionally, print the first few results
if len(data['elements']) > 0:
    print(f"First result: {data['elements'][0]}")

# %% [markdown]
# ## Conclusions
#
# The below code is for marking purpuses only, and not part of your project. It helps us gather the data we need without asking you for database credentials, and scouring github pages. This is mandatory. If the code does not work for you, let us know immediately.

# %% [markdown]
# 1) Please re-run the code from Practical 1 to help us see the contents of your database. We recommend you include all data sources there, but some smaller inputs are fine to use as files.

# %%
tables = %sql SHOW TABLES;

for row in tables:
    table_name = row[0]
    print(f"\nTable: {table_name}")

    table_status = %sql SHOW TABLE STATUS LIKE '{table_name}';
    approx_row_count = table_status[0][4] if table_status else 'Unable to fetch row count'
    print("\nApprox Row Count:", approx_row_count//100000/10, "M")

    first_5_rows = %sql SELECT * FROM `{table_name}` LIMIT 5;
    print(first_5_rows)

    indices = %sql SHOW INDEX FROM `{table_name}`;
    if indices:
        print("\nIndices:")
        for index in indices:
            print(f" - {index[2]} ({index[10]}): Column {index[4]}")
    else:
        print("\nNo indices set on this table.")

# %% [markdown]
# 2) Please paste a link to your fynesse library below, and make sure it's publically accessible. Also run the code below, and make sure it worked, printing out the contents of your library.

# %%
fynesse_url = '<your-url-library-here>'

# %%
import fynesse
import os

print('FYNESSE STRUCTURE:')
package_path = os.path.dirname(fynesse.__file__)
for root, dirs, files in os.walk(package_path):
    level = root.replace(package_path, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
    sub_indent = ' ' * 4 * (level + 1)
    for f in files:
        print(f"{sub_indent}{f}")

print('FILE CONTENTS')
for root, dirs, files in os.walk(package_path):
    for file in files:
        file_path = os.path.join(root, file)
        print(f"--- Contents of {file_path} ---\n")
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                print(f.read())
        except Exception as e:
            print(f"Could not read {file_path}: {e}")
        print("\n" + "-" * 50 + "\n")
